# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate

def rk4(func, y0, x):
    y0 = np.array(y0)
    n = len(x)
    f = lambda xi,yi: np.array(func(yi,xi))
    y = np.zeros( (n,) + y0.shape)
    h = (x[n-1] - x[0])/(n-1) 
    xi = x[0]
    y[0] = yi = y0[:]
    for i in range(1, n):
        k1 = h * f(xi, yi)
        k2 = h * f(xi + 0.5 * h, yi + 0.5 * k1)
        k3 = h * f(xi + 0.5 * h, yi + 0.5 * k2)
        k4 = h * f(xi + h, yi + k3)
        xi = x[i]
        y[i] = yi = yi + (k1 + 2*(k2 + k3) + k4) / 6
    return y

def bisect(z, del_z, zc):
    global lp, lm, z_minus, z_plus
    if zc > 0.:
        lp = 1
        z_plus = z
    else:
        lm = 1
        z_minus = z
    if lp*lm == 0:
        z += (lm - lp)*del_z
        return(z)
    else:
        z = 0.5*(z_plus + z_minus)
        return z
    
def potential(x):
    if x>= -1. and x<= 1.: return -1.
    else: return 0

def derivs(y0, x):

    dydx = np.zeros_like(y0)
    dydx[0] = y0[1]
    dydx[1] = lam*(potential(x)-E)*y0[0]

    return dydx


n_steps = 10000
tol = 1.e-5
x0 = -1.3 # x=0
xn = -x0 # x=1m

coeff_lam = 0.1
lam = coeff_lam*np.pi*np.pi #람다값
n_lam = str(coeff_lam)


E_i = -0.9999
a_asymp = 0.02 #점근거동에서 앞의 상수 (시행착오를 통해 결정)
del_E = 0.03#에너지 증가값

yn = 0 # An exact value of y at right point.
# create a x array from x0 to xn.
x = np.linspace(x0, xn, n_steps+1)

E = E_i
E_all = []

for nth in range(100): #여기서는 쏘아보기 법으로 에너지의 값만 구해줄거임. 에너지는 연산 과정에서만 존재하고, 따로 저장은 해놓지 않음.
    del_k = (-1)**(nth+1) * 0.5
    
    #global variable set for function bisect()
    loop = lp = lm = 0
    z_plus = z_ninus = 0.
    yc = 100000
    E_old = -100000
    
    while np.fabs(yc)>tol and np.fabs(E_old - E) > 1.e-100  and E < 0: #np.fabs는 절댓값을 반환하라 / 세 조건중에 하나라도 틀리면 바로 브레이크
        y00 = a_asymp*lam*lam*np.fabs(E)*np.exp(np.sqrt(lam*np.fabs(E))*x0)
        y01 = np.sqrt(lam*np.fabs(E))*y00
        y0 = [y00, y01]
        y = rk4(derivs, y0, x)
        yc = ((-1)**nth)*(((-1)**nth)*y00 - y[-1,0])/y00
        E= bisect(E, del_E, yc)
        loop += 1
        print('%dth bound state, loop = %d,  E = %.5f pi, yc = %.5e' % (nth+1, loop, E, yc))
        if loop > 100000: break #루프탈출 문
#    input()
#    print('\n')
    E_all.append(E) # append all k's to k_all #구한 k번째 에너지를 배열에 따로 저장.
    E = E + np.fabs(del_E) #다음 에너지를 구하기 위해 세팅해주는 초기값을, 바로 전단계 E보다 조금 더 큰 값에서 시작하자.
    if E > 0: break # n 번째 구속상태까지 계산하고 n+1번째를 계산하려고 했더니 E가 0보다 크네? 구속상태 없는것이 된다.

fig = plt.figure(figsize=(12,8))
ax = plt.gca()
plt.xlim(-3,3)
plt.ylim(-1.5, 1.5)
plt.title(r'Wave functions of time-independent Schr$\..{o}$dinger equation for a potential well case.')

for iE in range(len(E_all)-1): #위에서 구한 에너지의 값에서, 실제 y값들을 구하는 과정. 
    E = E_all[iE]
    y = rk4(derivs, y0, x)
    y[:,0] /= np.sqrt(integrate.simps(y[:,0]*y[:,0],x)) # 솔루션의 규격화 과정
    plt.text(0.7, 0.95-iE*0.04, r'%dth bound state energy = %.5f $U_0$' % (iE+1, E), transform=ax.transAxes)    
    line, = ax.plot(x,y[:,0], lw=0.8)
    ax.plot([x0, -1, -1, 1, 1, xn], [0, 0, -1, -1, 0, 0 ], 'b', lw=5, alpha=0.05)
plt.grid()
print(E_all)
#plt.savefig('square_potential_well_%s.png' %(n_lam))
plt.show()
# Out:
# 1th bound state, loop = 1,  E = -0.96990 pi, yc = -3.61066e+00
# 1th bound state, loop = 2,  E = -0.93990 pi, yc = -3.35332e+00
# 1th bound state, loop = 3,  E = -0.90990 pi, yc = -3.10367e+00
# 1th bound state, loop = 4,  E = -0.87990 pi, yc = -2.86158e+00
# 1th bound state, loop = 5,  E = -0.84990 pi, yc = -2.62689e+00
# 1th bound state, loop = 6,  E = -0.81990 pi, yc = -2.39947e+00
# 1th bound state, loop = 7,  E = -0.78990 pi, yc = -2.17917e+00
# 1th bound state, loop = 8,  E = -0.75990 pi, yc = -1.96586e+00
# 1th bound state, loop = 9,  E = -0.72990 pi, yc = -1.75941e+00
# 1th bound state, loop = 10,  E = -0.69990 pi, yc = -1.55966e+00
# 1th bound state, loop = 11,  E = -0.66990 pi, yc = -1.36650e+00
# 1th bound state, loop = 12,  E = -0.63990 pi, yc = -1.17979e+00
# 1th bound state, loop = 13,  E = -0.60990 pi, yc = -9.99405e-01
# 1th bound state, loop = 14,  E = -0.57990 pi, yc = -8.25206e-01
# 1th bound state, loop = 15,  E = -0.54990 pi, yc = -6.57071e-01
# 1th bound state, loop = 16,  E = -0.51990 pi, yc = -4.94871e-01
# 1th bound state, loop = 17,  E = -0.48990 pi, yc = -3.38481e-01
# 1th bound state, loop = 18,  E = -0.45990 pi, yc = -1.87773e-01
# 1th bound state, loop = 19,  E = -0.42990 pi, yc = -4.26228e-02
# 1th bound state, loop = 20,  E = -0.44490 pi, yc = 9.70985e-02
# 1th bound state, loop = 21,  E = -0.45240 pi, yc = 2.79086e-02
# 1th bound state, loop = 22,  E = -0.44865 pi, yc = -7.18842e-03
# 1th bound state, loop = 23,  E = -0.45052 pi, yc = 1.04021e-02
# 1th bound state, loop = 24,  E = -0.45146 pi, yc = 1.61738e-03
# 1th bound state, loop = 25,  E = -0.45099 pi, yc = -2.78289e-03
# 1th bound state, loop = 26,  E = -0.45076 pi, yc = -5.82099e-04
# 1th bound state, loop = 27,  E = -0.45088 pi, yc = 5.17803e-04
# 1th bound state, loop = 28,  E = -0.45082 pi, yc = -3.21069e-05
# 1th bound state, loop = 29,  E = -0.45085 pi, yc = 2.42858e-04
# 1th bound state, loop = 30,  E = -0.45086 pi, yc = 1.05378e-04
# 1th bound state, loop = 31,  E = -0.45087 pi, yc = 3.66363e-05
# 1th bound state, loop = 32,  E = -0.45087 pi, yc = 2.26487e-06
# 2th bound state, loop = 1,  E = -0.45087 pi, yc = 1.86190e+00
# 2th bound state, loop = 2,  E = -0.48087 pi, yc = 2.00001e+00
# 2th bound state, loop = 3,  E = -0.51087 pi, yc = 2.14352e+00
# 2th bound state, loop = 4,  E = -0.54087 pi, yc = 2.29254e+00
# 2th bound state, loop = 5,  E = -0.57087 pi, yc = 2.44721e+00
# 2th bound state, loop = 6,  E = -0.60087 pi, yc = 2.60765e+00
# 2th bound state, loop = 7,  E = -0.63087 pi, yc = 2.77398e+00
# 2th bound state, loop = 8,  E = -0.66087 pi, yc = 2.94634e+00
# 2th bound state, loop = 9,  E = -0.69087 pi, yc = 3.12486e+00
# 2th bound state, loop = 10,  E = -0.72087 pi, yc = 3.30965e+00
# 2th bound state, loop = 11,  E = -0.75087 pi, yc = 3.50086e+00
# 2th bound state, loop = 12,  E = -0.78087 pi, yc = 3.69860e+00
# 2th bound state, loop = 13,  E = -0.81087 pi, yc = 3.90303e+00
# 2th bound state, loop = 14,  E = -0.84087 pi, yc = 4.11426e+00
# 2th bound state, loop = 15,  E = -0.87087 pi, yc = 4.33244e+00
# 2th bound state, loop = 16,  E = -0.90087 pi, yc = 4.55770e+00
# 2th bound state, loop = 17,  E = -0.93087 pi, yc = 4.79019e+00
# 2th bound state, loop = 18,  E = -0.96087 pi, yc = 5.03004e+00
# 2th bound state, loop = 19,  E = -0.99087 pi, yc = 5.27740e+00
# 2th bound state, loop = 20,  E = -1.02087 pi, yc = 5.53241e+00
# 2th bound state, loop = 21,  E = -1.05087 pi, yc = 5.79522e+00
# 2th bound state, loop = 22,  E = -1.08087 pi, yc = 6.06599e+00
# 2th bound state, loop = 23,  E = -1.11087 pi, yc = 6.34485e+00
# 2th bound state, loop = 24,  E = -1.14087 pi, yc = 6.63197e+00
# 2th bound state, loop = 25,  E = -1.17087 pi, yc = 6.92750e+00
# 2th bound state, loop = 26,  E = -1.20087 pi, yc = 7.23160e+00
# 2th bound state, loop = 27,  E = -1.23087 pi, yc = 7.54442e+00
# 2th bound state, loop = 28,  E = -1.26087 pi, yc = 7.86614e+00
# 2th bound state, loop = 29,  E = -1.29087 pi, yc = 8.19691e+00
# 2th bound state, loop = 30,  E = -1.32087 pi, yc = 8.53690e+00
# 2th bound state, loop = 31,  E = -1.35087 pi, yc = 8.88628e+00
# 2th bound state, loop = 32,  E = -1.38087 pi, yc = 9.24523e+00
# 2th bound state, loop = 33,  E = -1.41087 pi, yc = 9.61390e+00
# 2th bound state, loop = 34,  E = -1.44087 pi, yc = 9.99249e+00
# 2th bound state, loop = 35,  E = -1.47087 pi, yc = 1.03812e+01
# 2th bound state, loop = 36,  E = -1.50087 pi, yc = 1.07801e+01
# 2th bound state, loop = 37,  E = -1.53087 pi, yc = 1.11895e+01
# 2th bound state, loop = 38,  E = -1.56087 pi, yc = 1.16095e+01
# 2th bound state, loop = 39,  E = -1.59087 pi, yc = 1.20404e+01
# 2th bound state, loop = 40,  E = -1.62087 pi, yc = 1.24823e+01
# 2th bound state, loop = 41,  E = -1.65087 pi, yc = 1.29354e+01
# 2th bound state, loop = 42,  E = -1.68087 pi, yc = 1.33999e+01
# 2th bound state, loop = 43,  E = -1.71087 pi, yc = 1.38760e+01
# 2th bound state, loop = 44,  E = -1.74087 pi, yc = 1.43639e+01
# 2th bound state, loop = 45,  E = -1.77087 pi, yc = 1.48638e+01
# 2th bound state, loop = 46,  E = -1.80087 pi, yc = 1.53759e+01
# 2th bound state, loop = 47,  E = -1.83087 pi, yc = 1.59005e+01
# 2th bound state, loop = 48,  E = -1.86087 pi, yc = 1.64376e+01
# 2th bound state, loop = 49,  E = -1.89087 pi, yc = 1.69877e+01
# 2th bound state, loop = 50,  E = -1.92087 pi, yc = 1.75508e+01
# 2th bound state, loop = 51,  E = -1.95087 pi, yc = 1.81272e+01
# 2th bound state, loop = 52,  E = -1.98087 pi, yc = 1.87171e+01
# 2th bound state, loop = 53,  E = -2.01087 pi, yc = 1.93207e+01
# 2th bound state, loop = 54,  E = -2.04087 pi, yc = 1.99384e+01
# 2th bound state, loop = 55,  E = -2.07087 pi, yc = 2.05702e+01
# 2th bound state, loop = 56,  E = -2.10087 pi, yc = 2.12164e+01
# 2th bound state, loop = 57,  E = -2.13087 pi, yc = 2.18773e+01
# 2th bound state, loop = 58,  E = -2.16087 pi, yc = 2.25532e+01
# 2th bound state, loop = 59,  E = -2.19087 pi, yc = 2.32441e+01
# 2th bound state, loop = 60,  E = -2.22087 pi, yc = 2.39505e+01
# 2th bound state, loop = 61,  E = -2.25087 pi, yc = 2.46726e+01
# 2th bound state, loop = 62,  E = -2.28087 pi, yc = 2.54105e+01
# 2th bound state, loop = 63,  E = -2.31087 pi, yc = 2.61646e+01
# 2th bound state, loop = 64,  E = -2.34087 pi, yc = 2.69352e+01
# 2th bound state, loop = 65,  E = -2.37087 pi, yc = 2.77224e+01
# 2th bound state, loop = 66,  E = -2.40087 pi, yc = 2.85266e+01
# 2th bound state, loop = 67,  E = -2.43087 pi, yc = 2.93480e+01
# 2th bound state, loop = 68,  E = -2.46087 pi, yc = 3.01869e+01
# 2th bound state, loop = 69,  E = -2.49087 pi, yc = 3.10436e+01
# 2th bound state, loop = 70,  E = -2.52087 pi, yc = 3.19183e+01
# 2th bound state, loop = 71,  E = -2.55087 pi, yc = 3.28113e+01
# 2th bound state, loop = 72,  E = -2.58087 pi, yc = 3.37230e+01
# 2th bound state, loop = 73,  E = -2.61087 pi, yc = 3.46536e+01
# 2th bound state, loop = 74,  E = -2.64087 pi, yc = 3.56034e+01
# 2th bound state, loop = 75,  E = -2.67087 pi, yc = 3.65727e+01
# 2th bound state, loop = 76,  E = -2.70087 pi, yc = 3.75619e+01
# 2th bound state, loop = 77,  E = -2.73087 pi, yc = 3.85711e+01
# 2th bound state, loop = 78,  E = -2.76087 pi, yc = 3.96007e+01
# 2th bound state, loop = 79,  E = -2.79087 pi, yc = 4.06511e+01
# 2th bound state, loop = 80,  E = -2.82087 pi, yc = 4.17226e+01
# 2th bound state, loop = 81,  E = -2.85087 pi, yc = 4.28154e+01
# 2th bound state, loop = 82,  E = -2.88087 pi, yc = 4.39299e+01
# 2th bound state, loop = 83,  E = -2.91087 pi, yc = 4.50664e+01
# 2th bound state, loop = 84,  E = -2.94087 pi, yc = 4.62253e+01
# 2th bound state, loop = 85,  E = -2.97087 pi, yc = 4.74068e+01
# 2th bound state, loop = 86,  E = -3.00087 pi, yc = 4.86114e+01
# 2th bound state, loop = 87,  E = -3.03087 pi, yc = 4.98394e+01
# 2th bound state, loop = 88,  E = -3.06087 pi, yc = 5.10911e+01
# 2th bound state, loop = 89,  E = -3.09087 pi, yc = 5.23668e+01
# 2th bound state, loop = 90,  E = -3.12087 pi, yc = 5.36670e+01
# 2th bound state, loop = 91,  E = -3.15087 pi, yc = 5.49920e+01
# 2th bound state, loop = 92,  E = -3.18087 pi, yc = 5.63421e+01
# 2th bound state, loop = 93,  E = -3.21087 pi, yc = 5.77178e+01
# 2th bound state, loop = 94,  E = -3.24087 pi, yc = 5.91194e+01
# 2th bound state, loop = 95,  E = -3.27087 pi, yc = 6.05472e+01
# 2th bound state, loop = 96,  E = -3.30087 pi, yc = 6.20017e+01
# 2th bound state, loop = 97,  E = -3.33087 pi, yc = 6.34832e+01
# 2th bound state, loop = 98,  E = -3.36087 pi, yc = 6.49922e+01
# 2th bound state, loop = 99,  E = -3.39087 pi, yc = 6.65290e+01
# 2th bound state, loop = 100,  E = -3.42087 pi, yc = 6.80941e+01
# 2th bound state, loop = 101,  E = -3.45087 pi, yc = 6.96878e+01
# 2th bound state, loop = 102,  E = -3.48087 pi, yc = 7.13105e+01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/yl/2yyp8sls31nb3myshphd8s2r0000gp/T/ipykernel_2063/326591538.py in <module>
#      82         y01 = np.sqrt(lam*np.fabs(E))*y00
#      83         y0 = [y00, y01]
# ---> 84         y = rk4(derivs, y0, x)
#      85         yc = ((-1)**nth)*(((-1)**nth)*y00 - y[-1,0])/y00
#      86         E= bisect(E, del_E, yc)
#
# /var/folders/yl/2yyp8sls31nb3myshphd8s2r0000gp/T/ipykernel_2063/326591538.py in rk4(func, y0, x)
#      14         k1 = h * f(xi, yi)
#      15         k2 = h * f(xi + 0.5 * h, yi + 0.5 * k1)
# ---> 16         k3 = h * f(xi + 0.5 * h, yi + 0.5 * k2)
#      17         k4 = h * f(xi + h, yi + k3)
#      18         xi = x[i]
#
# KeyboardInterrupt:
